# %% [markdown]
# ## Realizando a conexão com o MongoDB

# %% [markdown]
# Nesse momento vamos utilizar o código fornecido no MongoDB Atlas para realizarmos a conexão com o nosso banco de dados utilizando a biblioteca pymongo.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://pvreboucas:12345@cluster-pipeline.r7drw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster-pipeline"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ## Criando o banco de dados e uma coleção

# %% [markdown]
# Conectados ao banco de dados, está tudo pronto para realizar operações nele. Primeiramente, vamos criar nossa base de dados chamada "db_produtos" e uma coleção dentro dela chamada "produtos". Vale lembrar que para um banco de dados do MongoDB ser efetivamente criado, ele precisa conter dados.

# %%
db = client["db_produtos"]
collection = db["produtos"]

# %%
client.list_database_names()
# Out:
# ['sample_mflix', 'admin', 'local']

# %%
product = {"produto": "computador", "quantidade": 77}
collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('670ade431d6415c0d0a940c3'), acknowledged=True)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('670ade431d6415c0d0a940c3'),
#  'produto': 'computador',
#  'quantidade': 77}

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'sample_mflix', 'admin', 'local']

# %% [markdown]
# ## Extraindo os dados da API

# %% [markdown]
# Agora que nossa base de dados e coleção estão criadas, podemos prosseguir para a etapa de extração dos dados que desejamos adicionar a esse banco de dados.

# %% [markdown]
# Como já sabemos, os registros referentes aos produtos vendidos pela empresa de e-commerce estão armazenados em uma API. A URL que nos permite acessar esses dados é: https://labdados.com/produtos

# %%
import requests

response = requests.get("https://labdados.com/produtos")
response.json()
# Out:
# [{'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 92.45,
#   'Frete': 5.6096965236,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 43.84,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 87.18,
#   'Frete': 2.2265117938,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Corda de pular',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 13.65,
#   'Frete': 1.2579259604,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Dinossauro Rex',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 28.32,
#   'Frete': 2.0390593271,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_debito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Jogo de copos',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 54.67,
#   'Frete': 9.2906273957,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Lavadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1920.01,
#   'Frete': 99.8191954012,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'ES',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -19.19,
#   'lon': -40.34},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 56.26,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Xadrez de madeira',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 25.87,
#   'Frete': 1.9086041977,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Xadrez de madeira',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 25.23,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Impressora',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 322.04,
#   'Frete': 14.7321002401,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Mesa de centro',
#   'Categoria do Produto': 'moveis',
#   'Preço': 282.22,
#   'Frete': 12.6118050347,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Tablet ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1100.42,
#   'Frete': 68.4513476183,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Fogão',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 791.81,
#   'Frete': 42.4446263246,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Violão',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 316.84,
#   'Frete': 17.1595536296,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Geladeira',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 2322.94,
#   'Frete': 121.2740057251,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Secadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1893.04,
#   'Frete': 107.1782993366,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Jogo de copos',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 37.44,
#   'Frete': 2.8819825404,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Blocos de montar',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 36.84,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 63.25,
#   'Frete': 3.894137208,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Fogão',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 607.49,
#   'Frete': 33.2354300998,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 75.11,
#   'Frete': 1.5838206052,
#   'Data da Compra': '01/01/2022',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bateria',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 1031.24,
#   'Frete': 55.199204426,
#   'Data da Compra': '01/01/2023',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Boneca bebê',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 50.72,
#   'Frete': 3.2317919389,
#   'Data da Compra': '01/01/2023',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Sofá retrátil',
#   'Categoria do Produto': 'moveis',
#   'Preço': 888.09,
#   'Frete': 51.7681594786,
#   'Data da Compra': '01/01/2023',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 20,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 47.05,
#   'Frete': 2.7883968633,
#   'Data da Compra': '01/01/2023',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 6,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 836.66,
#   'Frete': 45.438043164,
#   'Data da Compra': '01/01/2023',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Xadrez de madeira',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 44.82,
#   'Frete': 3.2749453383,
#   'Data da Compra': '01/01/2023',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Lavadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1857.13,
#   'Frete': 99.169711412,
#   'Data da Compra': '01/02/2020',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Mochila',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 123.53,
#   'Frete': 4.1620399383,
#   'Data da Compra': '01/02/2020',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Headset',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 309.35,
#   'Frete': 16.755082759,
#   'Data da Compra': '01/02/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Micro-ondas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1035.84,
#   'Frete': 55.6864683002,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 6,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Cama king',
#   'Categoria do Produto': 'moveis',
#   'Preço': 660.46,
#   'Frete': 35.4506339784,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 86.13,
#   'Frete': 5.2731755368,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Guitarra',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 957.84,
#   'Frete': 51.5283634201,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 72.75,
#   'Frete': 1.458157705,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Cama box',
#   'Categoria do Produto': 'moveis',
#   'Preço': 819.22,
#   'Frete': 43.9041263642,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Headset',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 340.22,
#   'Frete': 15.7001305473,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 61.73,
#   'Frete': 0.0,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Jogo de panelas',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 126.59,
#   'Frete': 4.3249757326,
#   'Data da Compra': '01/02/2021',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Guitarra',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 1158.33,
#   'Frete': 62.2086923009,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 57.63,
#   'Frete': 9.3105595123,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Copo térmico',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 50.31,
#   'Frete': 0.0,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Corda de pular',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 21.88,
#   'Frete': 0.0,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'SC',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -27.45,
#   'lon': -50.95},
#  {'Produto': 'Mesa de jantar',
#   'Categoria do Produto': 'moveis',
#   'Preço': 264.63,
#   'Frete': 14.6218559113,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 79.28,
#   'Frete': 1.8058605601,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 520.28,
#   'Frete': 27.9864706964,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Mochila',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 147.99,
#   'Frete': 5.4644613527,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Poltrona',
#   'Categoria do Produto': 'moveis',
#   'Preço': 251.37,
#   'Frete': 10.969135344,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'AL',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -9.62,
#   'lon': -36.82},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 41.76,
#   'Frete': 2.7546988942,
#   'Data da Compra': '01/02/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 82.15,
#   'Frete': 1.958679426,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Smartwatch',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 184.84,
#   'Frete': 17.9198218199,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 55.1,
#   'Frete': 3.2170351457,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Cômoda',
#   'Categoria do Produto': 'moveis',
#   'Preço': 417.02,
#   'Frete': 19.7894995019,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Fone de ouvido',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 108.12,
#   'Frete': 6.6969125635,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Lava louças',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1702.95,
#   'Frete': 88.2614034053,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'TV Led UHD 4K',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 2404.01,
#   'Frete': 125.5907393338,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 70.49,
#   'Frete': 1.337819504,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 40.98,
#   'Frete': 0.0,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Assistente virtual',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 214.5,
#   'Frete': 9.0059187638,
#   'Data da Compra': '01/02/2023',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Jogo de panelas',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 229.47,
#   'Frete': 9.803026228,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 9,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Cama box',
#   'Categoria do Produto': 'moveis',
#   'Preço': 467.81,
#   'Frete': 25.4405796638,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Bola de basquete',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 46.18,
#   'Frete': 10.2609556896,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Lava louças',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1451.86,
#   'Frete': 74.8916162854,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Cadeira de escritório',
#   'Categoria do Produto': 'moveis',
#   'Preço': 577.67,
#   'Frete': 28.3436287018,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Cubo mágico 8x8',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 21.43,
#   'Frete': 1.672187555,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bola de basquete',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 82.3,
#   'Frete': 1.9666664748,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Smart TV',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1917.3,
#   'Frete': 99.674896054,
#   'Data da Compra': '01/03/2020',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Geladeira',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 2774.0,
#   'Frete': 147.9902805969,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Lavadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 2034.43,
#   'Frete': 108.8583816384,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Celular ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1522.65,
#   'Frete': 87.3184671407,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Xadrez de madeira',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 28.76,
#   'Frete': 0.0,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Fogão',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1378.02,
#   'Frete': 74.7745347061,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'MS',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -20.51,
#   'lon': -54.54},
#  {'Produto': 'Cubo mágico 8x8',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 14.52,
#   'Frete': 3.9369626407,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'DF',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -15.83,
#   'lon': -47.86},
#  {'Produto': 'Micro-ondas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 930.94,
#   'Frete': 47.1541934231,
#   'Data da Compra': '01/03/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Corda de pular',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 32.96,
#   'Frete': 11.3359643772,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Celular ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1100.5,
#   'Frete': 59.2853264023,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 54.42,
#   'Frete': 3.1808271914,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Guarda roupas',
#   'Categoria do Produto': 'moveis',
#   'Preço': 663.54,
#   'Frete': 36.0185209544,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Lavadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 2060.2,
#   'Frete': 107.2838911531,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'PB',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -7.28,
#   'lon': -36.72},
#  {'Produto': 'Carrinho controle remoto',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 116.0,
#   'Frete': 3.7610900916,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Sofá retrátil',
#   'Categoria do Produto': 'moveis',
#   'Preço': 890.4,
#   'Frete': 44.9955603837,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Mesa de jantar',
#   'Categoria do Produto': 'moveis',
#   'Preço': 476.88,
#   'Frete': 22.9768644188,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 50.51,
#   'Frete': 10.2450858314,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 6,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Headset',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 219.88,
#   'Frete': 11.9967253244,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'CE',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -5.2,
#   'lon': -39.53},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 109.52,
#   'Frete': 3.416049586,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Lavadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1732.36,
#   'Frete': 89.8273974282,
#   'Data da Compra': '01/03/2022',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 71.64,
#   'Frete': 1.3990535443,
#   'Data da Compra': '01/03/2023',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bateria',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 535.83,
#   'Frete': 26.1157745734,
#   'Data da Compra': '01/03/2023',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 8,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 43.35,
#   'Frete': 3.2481049178,
#   'Data da Compra': '01/03/2023',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Dinossauro Rex',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 28.71,
#   'Frete': 2.2157332793,
#   'Data da Compra': '01/03/2023',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 7,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 406.16,
#   'Frete': 22.3138102573,
#   'Data da Compra': '01/03/2023',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'PA',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 6,
#   'lat': -3.79,
#   'lon': -52.48},
#  {'Produto': 'Cama box',
#   'Categoria do Produto': 'moveis',
#   'Preço': 834.98,
#   'Frete': 44.9912775682,
#   'Data da Compra': '01/03/2023',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 65.86,
#   'Frete': 4.4466946987,
#   'Data da Compra': '01/04/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Assistente virtual',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 250.29,
#   'Frete': 16.4910058494,
#   'Data da Compra': '01/04/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Panela de pressão',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 83.2,
#   'Frete': 2.0145887672,
#   'Data da Compra': '01/04/2020',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Fogão',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1026.47,
#   'Frete': 64.5137325897,
#   'Data da Compra': '01/04/2020',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Assistente virtual',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 180.46,
#   'Frete': 10.295964254,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Boneca bebê',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 67.88,
#   'Frete': 4.1406707791,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 773.72,
#   'Frete': 41.729366863,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Lavadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1822.44,
#   'Frete': 94.6238864312,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'MS',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -20.51,
#   'lon': -54.54},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 58.75,
#   'Frete': 6.292077079,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Guitarra',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 892.6,
#   'Frete': 48.0545296884,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Panela de pressão',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 94.58,
#   'Frete': 2.6205395316,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'DF',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -15.83,
#   'lon': -47.86},
#  {'Produto': 'Mesa de centro',
#   'Categoria do Produto': 'moveis',
#   'Preço': 217.42,
#   'Frete': 19.3750120217,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_debito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 83.18,
#   'Frete': 5.1160969115,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Boneca bebê',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 51.2,
#   'Frete': 3.2573504949,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 40.85,
#   'Frete': 0.0,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Celular ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1578.34,
#   'Frete': 81.6262957825,
#   'Data da Compra': '01/04/2021',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Guarda roupas',
#   'Categoria do Produto': 'moveis',
#   'Preço': 666.47,
#   'Frete': 33.0719615556,
#   'Data da Compra': '01/04/2022',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'MA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -5.42,
#   'lon': -45.44},
#  {'Produto': 'Cômoda',
#   'Categoria do Produto': 'moveis',
#   'Preço': 331.48,
#   'Frete': 15.2347518407,
#   'Data da Compra': '01/04/2022',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Impressora',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 363.8,
#   'Frete': 20.0582676933,
#   'Data da Compra': '01/04/2022',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Faqueiro',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 76.93,
#   'Frete': 4.9847062385,
#   'Data da Compra': '01/04/2022',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 75.04,
#   'Frete': 1.5800933158,
#   'Data da Compra': '01/04/2022',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'RO',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 7,
#   'lat': -10.83,
#   'lon': -63.34},
#  {'Produto': 'Micro-ondas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 677.31,
#   'Frete': 33.6491589445,
#   'Data da Compra': '01/04/2022',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Panela de pressão',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 73.64,
#   'Frete': 4.4522129863,
#   'Data da Compra': '01/05/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 7,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Jogo de tabuleiro',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 231.34,
#   'Frete': 9.9025981023,
#   'Data da Compra': '01/05/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Sofá retrátil',
#   'Categoria do Produto': 'moveis',
#   'Preço': 872.54,
#   'Frete': 46.986395037,
#   'Data da Compra': '01/05/2020',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Corda de pular',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 20.28,
#   'Frete': 8.1661520605,
#   'Data da Compra': '01/05/2020',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Headset',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 191.4,
#   'Frete': 10.4802510037,
#   'Data da Compra': '01/05/2020',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Micro-ondas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 409.25,
#   'Frete': 31.6486244366,
#   'Data da Compra': '01/05/2020',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Jogo de panelas',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 268.49,
#   'Frete': 14.8273892988,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Kit banquetas',
#   'Categoria do Produto': 'moveis',
#   'Preço': 394.53,
#   'Frete': 21.533800584,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'SC',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -27.45,
#   'lon': -50.95},
#  {'Produto': 'Celular Plus X42',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 2842.86,
#   'Frete': 151.6568684382,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Geladeira',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 2405.84,
#   'Frete': 129.5028576086,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Headset',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 98.2,
#   'Frete': 2.8132936411,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Ciência de dados com python',
#   'Categoria do Produto': 'livros',
#   'Preço': 58.61,
#   'Frete': 4.0606540096,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Micro-ondas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1034.13,
#   'Frete': 55.5954159446,
#   'Data da Compra': '01/05/2021',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Tablet ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1642.22,
#   'Frete': 85.0277136057,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 6,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Mesa de jantar',
#   'Categoria do Produto': 'moveis',
#   'Preço': 360.0,
#   'Frete': 19.4520428834,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Sofá retrátil',
#   'Categoria do Produto': 'moveis',
#   'Preço': 895.8,
#   'Frete': 45.2830941384,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 9,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Cadeira de escritório',
#   'Categoria do Produto': 'moveis',
#   'Preço': 619.44,
#   'Frete': 33.5144209995,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Mesa de centro',
#   'Categoria do Produto': 'moveis',
#   'Preço': 282.19,
#   'Frete': 12.6102076249,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Tablet ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1754.04,
#   'Frete': 93.6804790483,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 8,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Mochila',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 132.49,
#   'Frete': 4.639132983,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Mesa de centro',
#   'Categoria do Produto': 'moveis',
#   'Preço': 277.62,
#   'Frete': 15.0712066192,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SC',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -27.45,
#   'lon': -50.95},
#  {'Produto': 'Cadeira de escritório',
#   'Categoria do Produto': 'moveis',
#   'Preço': 403.02,
#   'Frete': 21.9907070783,
#   'Data da Compra': '01/05/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Corda de pular',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 24.57,
#   'Frete': 8.8638588693,
#   'Data da Compra': '01/06/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 46.58,
#   'Frete': 0.0,
#   'Data da Compra': '01/06/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 57.53,
#   'Frete': 0.0,
#   'Data da Compra': '01/06/2020',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Dashboards com Power BI',
#   'Categoria do Produto': 'livros',
#   'Preço': 42.09,
#   'Frete': 0.0,
#   'Data da Compra': '01/06/2020',
#   'Vendedor': 'Felipe Santos',
# ...
#  {'Produto': 'Faqueiro',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 57.29,
#   'Frete': 3.5816246737,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 4,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 572.39,
#   'Frete': 31.0091500449,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'DF',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -15.83,
#   'lon': -47.86},
#  {'Produto': 'Smart TV',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 2241.41,
#   'Frete': 120.2367546089,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 8,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Faqueiro',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 77.17,
#   'Frete': 1.6935094079,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Mesa de centro',
#   'Categoria do Produto': 'moveis',
#   'Preço': 154.52,
#   'Frete': 5.8121642078,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'ES',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -19.19,
#   'lon': -40.34},
#  {'Produto': 'Boneca bebê',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 76.32,
#   'Frete': 4.3469363074,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RS',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -30.17,
#   'lon': -53.5},
#  {'Produto': 'Celular ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1304.21,
#   'Frete': 67.0296979762,
#   'Data da Compra': '04/01/2023',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Cama box',
#   'Categoria do Produto': 'moveis',
#   'Preço': 441.88,
#   'Frete': 23.8175574588,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'TV Led UHD 4K',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 2828.89,
#   'Frete': 148.2143211233,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Beatriz Moraes',
#   'Local da compra': 'SE',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 6,
#   'lat': -10.57,
#   'lon': -37.45},
#  {'Produto': 'Cadeira de escritório',
#   'Categoria do Produto': 'moveis',
#   'Preço': 369.93,
#   'Frete': 20.2287641263,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Lava louças',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1983.51,
#   'Frete': 103.2003793676,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Lava louças',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1465.37,
#   'Frete': 78.9149592505,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Fogão',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 790.74,
#   'Frete': 39.6889652012,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Smartwatch',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 282.35,
#   'Frete': 12.6187271436,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'MS',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -20.51,
#   'lon': -54.54},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 53.15,
#   'Frete': 3.1188544155,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SC',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -27.45,
#   'lon': -50.95},
#  {'Produto': 'Lava louças',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1501.36,
#   'Frete': 86.3225176682,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -24.89,
#   'lon': -51.55},
#  {'Produto': 'Jogo de panelas',
#   'Categoria do Produto': 'utilidades domesticas',
#   'Preço': 291.96,
#   'Frete': 13.1304307328,
#   'Data da Compra': '04/02/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 8,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 70.28,
#   'Frete': 1.3266376358,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'TV Led UHD 4K',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 2053.75,
#   'Frete': 106.9404480573,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Tablet ABXY',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 1267.97,
#   'Frete': 73.8952022995,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Violão',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 476.63,
#   'Frete': 28.5429299273,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Carrinho controle remoto',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 112.45,
#   'Frete': 6.2764010172,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Isabella Pereira',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Lava louças',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 1999.81,
#   'Frete': 107.0149707893,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'GO',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -15.98,
#   'lon': -49.86},
#  {'Produto': 'Bola de basquete',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 88.85,
#   'Frete': 5.0197720155,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'PE',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 8,
#   'lat': -8.38,
#   'lon': -37.86},
#  {'Produto': 'Impressora',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 438.92,
#   'Frete': 32.4655559164,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Cama box',
#   'Categoria do Produto': 'moveis',
#   'Preço': 627.83,
#   'Frete': 33.961163259,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_debito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Blocos de montar',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 47.2,
#   'Frete': 0.0,
#   'Data da Compra': '04/02/2021',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Mesa de jantar',
#   'Categoria do Produto': 'moveis',
#   'Preço': 487.98,
#   'Frete': 27.3825823057,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'SC',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -27.45,
#   'lon': -50.95},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 60.51,
#   'Frete': 0.0,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'MT',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -12.64,
#   'lon': -55.42},
#  {'Produto': 'Dinossauro Rex',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 25.05,
#   'Frete': 0.0,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Bola de vôlei',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 52.26,
#   'Frete': 3.313792306,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Guarda roupas',
#   'Categoria do Produto': 'moveis',
#   'Preço': 601.04,
#   'Frete': 33.4026871756,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Lucas Oliveira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Dinossauro Rex',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 23.27,
#   'Frete': 0.0,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'MG',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -18.1,
#   'lon': -44.38},
#  {'Produto': 'Dinossauro Rex',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 22.01,
#   'Frete': 1.8589784356,
#   'Data da Compra': '04/02/2022',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Secadora de roupas',
#   'Categoria do Produto': 'eletrodomesticos',
#   'Preço': 884.14,
#   'Frete': 44.6622342163,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'SC',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -27.45,
#   'lon': -50.95},
#  {'Produto': 'Impressora',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 487.83,
#   'Frete': 32.2174152971,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Blocos de montar',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 52.35,
#   'Frete': 0.0,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Camila Ribeiro',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Mochila',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 129.95,
#   'Frete': 4.5038856243,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 5,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 104.17,
#   'Frete': 6.2337512651,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Felipe Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Blocos de montar',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 36.83,
#   'Frete': 2.4921912256,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Juliana Costa',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.25,
#   'lon': -42.66},
#  {'Produto': 'Smart TV',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 2327.65,
#   'Frete': 121.5247990555,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Bruno Rodrigues',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 91.35,
#   'Frete': 5.3952172075,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'cupom',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Cama king',
#   'Categoria do Produto': 'moveis',
#   'Preço': 597.95,
#   'Frete': 32.3701431501,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 4,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 996.07,
#   'Frete': 53.9261460943,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Larissa Alves',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Boneca bebê',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 55.95,
#   'Frete': 0.0,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Bianca Santos',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 2,
#   'Tipo de pagamento': 'boleto',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Bicicleta',
#   'Categoria do Produto': 'esporte e lazer',
#   'Preço': 901.92,
#   'Frete': 48.3076525693,
#   'Data da Compra': '04/02/2023',
#   'Vendedor': 'Pedro Gomes',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 10,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Cubo mágico 8x8',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 25.67,
#   'Frete': 0.0,
#   'Data da Compra': '04/03/2020',
#   'Vendedor': 'Rafael Costa',
#   'Local da compra': 'PR',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -24.89,
#   'lon': -51.55},
#  ...]

# %%
len(response.json())
# Out:
# 9435

# %% [markdown]
# ## Adicionando os dados extraídos na coleção

# %% [markdown]
# Com os dados extraídos no formato JSON, que é compatível com o MongoDB, podemos adicioná-los facilmente ao nosso banco de dados. Podemos utilizar o método `insert_many()` para adicionar todos os dados extraídos de uma vez.

# %%
docs = collection.insert_many(response.json())

# %%
docs.inserted_ids
# Out:
# [ObjectId('670adfd11d6415c0d0a940c4'),
#  ObjectId('670adfd11d6415c0d0a940c5'),
#  ObjectId('670adfd11d6415c0d0a940c6'),
#  ObjectId('670adfd11d6415c0d0a940c7'),
#  ObjectId('670adfd11d6415c0d0a940c8'),
#  ObjectId('670adfd11d6415c0d0a940c9'),
#  ObjectId('670adfd11d6415c0d0a940ca'),
#  ObjectId('670adfd11d6415c0d0a940cb'),
#  ObjectId('670adfd11d6415c0d0a940cc'),
#  ObjectId('670adfd11d6415c0d0a940cd'),
#  ObjectId('670adfd11d6415c0d0a940ce'),
#  ObjectId('670adfd11d6415c0d0a940cf'),
#  ObjectId('670adfd11d6415c0d0a940d0'),
#  ObjectId('670adfd11d6415c0d0a940d1'),
#  ObjectId('670adfd11d6415c0d0a940d2'),
#  ObjectId('670adfd11d6415c0d0a940d3'),
#  ObjectId('670adfd11d6415c0d0a940d4'),
#  ObjectId('670adfd11d6415c0d0a940d5'),
#  ObjectId('670adfd11d6415c0d0a940d6'),
#  ObjectId('670adfd11d6415c0d0a940d7'),
#  ObjectId('670adfd11d6415c0d0a940d8'),
#  ObjectId('670adfd11d6415c0d0a940d9'),
#  ObjectId('670adfd11d6415c0d0a940da'),
#  ObjectId('670adfd11d6415c0d0a940db'),
#  ObjectId('670adfd11d6415c0d0a940dc'),
#  ObjectId('670adfd11d6415c0d0a940dd'),
#  ObjectId('670adfd11d6415c0d0a940de'),
#  ObjectId('670adfd11d6415c0d0a940df'),
#  ObjectId('670adfd11d6415c0d0a940e0'),
#  ObjectId('670adfd11d6415c0d0a940e1'),
#  ObjectId('670adfd11d6415c0d0a940e2'),
#  ObjectId('670adfd11d6415c0d0a940e3'),
#  ObjectId('670adfd11d6415c0d0a940e4'),
#  ObjectId('670adfd11d6415c0d0a940e5'),
#  ObjectId('670adfd11d6415c0d0a940e6'),
#  ObjectId('670adfd11d6415c0d0a940e7'),
#  ObjectId('670adfd11d6415c0d0a940e8'),
#  ObjectId('670adfd11d6415c0d0a940e9'),
#  ObjectId('670adfd11d6415c0d0a940ea'),
#  ObjectId('670adfd11d6415c0d0a940eb'),
#  ObjectId('670adfd11d6415c0d0a940ec'),
#  ObjectId('670adfd11d6415c0d0a940ed'),
#  ObjectId('670adfd11d6415c0d0a940ee'),
#  ObjectId('670adfd11d6415c0d0a940ef'),
#  ObjectId('670adfd11d6415c0d0a940f0'),
#  ObjectId('670adfd11d6415c0d0a940f1'),
#  ObjectId('670adfd11d6415c0d0a940f2'),
#  ObjectId('670adfd11d6415c0d0a940f3'),
#  ObjectId('670adfd11d6415c0d0a940f4'),
#  ObjectId('670adfd11d6415c0d0a940f5'),
#  ObjectId('670adfd11d6415c0d0a940f6'),
#  ObjectId('670adfd11d6415c0d0a940f7'),
#  ObjectId('670adfd11d6415c0d0a940f8'),
#  ObjectId('670adfd11d6415c0d0a940f9'),
#  ObjectId('670adfd11d6415c0d0a940fa'),
#  ObjectId('670adfd11d6415c0d0a940fb'),
#  ObjectId('670adfd11d6415c0d0a940fc'),
#  ObjectId('670adfd11d6415c0d0a940fd'),
#  ObjectId('670adfd11d6415c0d0a940fe'),
#  ObjectId('670adfd11d6415c0d0a940ff'),
#  ObjectId('670adfd11d6415c0d0a94100'),
#  ObjectId('670adfd11d6415c0d0a94101'),
#  ObjectId('670adfd11d6415c0d0a94102'),
#  ObjectId('670adfd11d6415c0d0a94103'),
#  ObjectId('670adfd11d6415c0d0a94104'),
#  ObjectId('670adfd11d6415c0d0a94105'),
#  ObjectId('670adfd11d6415c0d0a94106'),
#  ObjectId('670adfd11d6415c0d0a94107'),
#  ObjectId('670adfd11d6415c0d0a94108'),
#  ObjectId('670adfd11d6415c0d0a94109'),
#  ObjectId('670adfd11d6415c0d0a9410a'),
#  ObjectId('670adfd11d6415c0d0a9410b'),
#  ObjectId('670adfd11d6415c0d0a9410c'),
#  ObjectId('670adfd11d6415c0d0a9410d'),
#  ObjectId('670adfd11d6415c0d0a9410e'),
#  ObjectId('670adfd11d6415c0d0a9410f'),
#  ObjectId('670adfd11d6415c0d0a94110'),
#  ObjectId('670adfd11d6415c0d0a94111'),
#  ObjectId('670adfd11d6415c0d0a94112'),
#  ObjectId('670adfd11d6415c0d0a94113'),
#  ObjectId('670adfd11d6415c0d0a94114'),
#  ObjectId('670adfd11d6415c0d0a94115'),
#  ObjectId('670adfd11d6415c0d0a94116'),
#  ObjectId('670adfd11d6415c0d0a94117'),
#  ObjectId('670adfd11d6415c0d0a94118'),
#  ObjectId('670adfd11d6415c0d0a94119'),
#  ObjectId('670adfd11d6415c0d0a9411a'),
#  ObjectId('670adfd11d6415c0d0a9411b'),
#  ObjectId('670adfd11d6415c0d0a9411c'),
#  ObjectId('670adfd11d6415c0d0a9411d'),
#  ObjectId('670adfd11d6415c0d0a9411e'),
#  ObjectId('670adfd11d6415c0d0a9411f'),
#  ObjectId('670adfd11d6415c0d0a94120'),
#  ObjectId('670adfd11d6415c0d0a94121'),
#  ObjectId('670adfd11d6415c0d0a94122'),
#  ObjectId('670adfd11d6415c0d0a94123'),
#  ObjectId('670adfd11d6415c0d0a94124'),
#  ObjectId('670adfd11d6415c0d0a94125'),
#  ObjectId('670adfd11d6415c0d0a94126'),
#  ObjectId('670adfd11d6415c0d0a94127'),
#  ObjectId('670adfd11d6415c0d0a94128'),
#  ObjectId('670adfd11d6415c0d0a94129'),
#  ObjectId('670adfd11d6415c0d0a9412a'),
#  ObjectId('670adfd11d6415c0d0a9412b'),
#  ObjectId('670adfd11d6415c0d0a9412c'),
#  ObjectId('670adfd11d6415c0d0a9412d'),
#  ObjectId('670adfd11d6415c0d0a9412e'),
#  ObjectId('670adfd11d6415c0d0a9412f'),
#  ObjectId('670adfd11d6415c0d0a94130'),
#  ObjectId('670adfd11d6415c0d0a94131'),
#  ObjectId('670adfd11d6415c0d0a94132'),
#  ObjectId('670adfd11d6415c0d0a94133'),
#  ObjectId('670adfd11d6415c0d0a94134'),
#  ObjectId('670adfd11d6415c0d0a94135'),
#  ObjectId('670adfd11d6415c0d0a94136'),
#  ObjectId('670adfd11d6415c0d0a94137'),
#  ObjectId('670adfd11d6415c0d0a94138'),
#  ObjectId('670adfd11d6415c0d0a94139'),
#  ObjectId('670adfd11d6415c0d0a9413a'),
#  ObjectId('670adfd11d6415c0d0a9413b'),
#  ObjectId('670adfd11d6415c0d0a9413c'),
#  ObjectId('670adfd11d6415c0d0a9413d'),
#  ObjectId('670adfd11d6415c0d0a9413e'),
#  ObjectId('670adfd11d6415c0d0a9413f'),
#  ObjectId('670adfd11d6415c0d0a94140'),
#  ObjectId('670adfd11d6415c0d0a94141'),
#  ObjectId('670adfd11d6415c0d0a94142'),
#  ObjectId('670adfd11d6415c0d0a94143'),
#  ObjectId('670adfd11d6415c0d0a94144'),
#  ObjectId('670adfd11d6415c0d0a94145'),
#  ObjectId('670adfd11d6415c0d0a94146'),
#  ObjectId('670adfd11d6415c0d0a94147'),
#  ObjectId('670adfd11d6415c0d0a94148'),
#  ObjectId('670adfd11d6415c0d0a94149'),
#  ObjectId('670adfd11d6415c0d0a9414a'),
#  ObjectId('670adfd11d6415c0d0a9414b'),
#  ObjectId('670adfd11d6415c0d0a9414c'),
#  ObjectId('670adfd11d6415c0d0a9414d'),
#  ObjectId('670adfd11d6415c0d0a9414e'),
#  ObjectId('670adfd11d6415c0d0a9414f'),
#  ObjectId('670adfd11d6415c0d0a94150'),
#  ObjectId('670adfd11d6415c0d0a94151'),
#  ObjectId('670adfd11d6415c0d0a94152'),
#  ObjectId('670adfd11d6415c0d0a94153'),
#  ObjectId('670adfd11d6415c0d0a94154'),
#  ObjectId('670adfd11d6415c0d0a94155'),
#  ObjectId('670adfd11d6415c0d0a94156'),
#  ObjectId('670adfd11d6415c0d0a94157'),
#  ObjectId('670adfd11d6415c0d0a94158'),
#  ObjectId('670adfd11d6415c0d0a94159'),
#  ObjectId('670adfd11d6415c0d0a9415a'),
#  ObjectId('670adfd11d6415c0d0a9415b'),
#  ObjectId('670adfd11d6415c0d0a9415c'),
#  ObjectId('670adfd11d6415c0d0a9415d'),
#  ObjectId('670adfd11d6415c0d0a9415e'),
#  ObjectId('670adfd11d6415c0d0a9415f'),
#  ObjectId('670adfd11d6415c0d0a94160'),
#  ObjectId('670adfd11d6415c0d0a94161'),
#  ObjectId('670adfd11d6415c0d0a94162'),
#  ObjectId('670adfd11d6415c0d0a94163'),
#  ObjectId('670adfd11d6415c0d0a94164'),
#  ObjectId('670adfd11d6415c0d0a94165'),
#  ObjectId('670adfd11d6415c0d0a94166'),
#  ObjectId('670adfd11d6415c0d0a94167'),
#  ObjectId('670adfd11d6415c0d0a94168'),
#  ObjectId('670adfd11d6415c0d0a94169'),
#  ObjectId('670adfd11d6415c0d0a9416a'),
#  ObjectId('670adfd11d6415c0d0a9416b'),
#  ObjectId('670adfd11d6415c0d0a9416c'),
#  ObjectId('670adfd11d6415c0d0a9416d'),
#  ObjectId('670adfd11d6415c0d0a9416e'),
#  ObjectId('670adfd11d6415c0d0a9416f'),
#  ObjectId('670adfd11d6415c0d0a94170'),
#  ObjectId('670adfd11d6415c0d0a94171'),
#  ObjectId('670adfd11d6415c0d0a94172'),
#  ObjectId('670adfd11d6415c0d0a94173'),
#  ObjectId('670adfd11d6415c0d0a94174'),
#  ObjectId('670adfd11d6415c0d0a94175'),
#  ObjectId('670adfd11d6415c0d0a94176'),
#  ObjectId('670adfd11d6415c0d0a94177'),
#  ObjectId('670adfd11d6415c0d0a94178'),
#  ObjectId('670adfd11d6415c0d0a94179'),
#  ObjectId('670adfd11d6415c0d0a9417a'),
#  ObjectId('670adfd11d6415c0d0a9417b'),
#  ObjectId('670adfd11d6415c0d0a9417c'),
#  ObjectId('670adfd11d6415c0d0a9417d'),
#  ObjectId('670adfd11d6415c0d0a9417e'),
#  ObjectId('670adfd11d6415c0d0a9417f'),
#  ObjectId('670adfd11d6415c0d0a94180'),
#  ObjectId('670adfd11d6415c0d0a94181'),
#  ObjectId('670adfd11d6415c0d0a94182'),
#  ObjectId('670adfd11d6415c0d0a94183'),
#  ObjectId('670adfd11d6415c0d0a94184'),
#  ObjectId('670adfd11d6415c0d0a94185'),
#  ObjectId('670adfd11d6415c0d0a94186'),
#  ObjectId('670adfd11d6415c0d0a94187'),
#  ObjectId('670adfd11d6415c0d0a94188'),
#  ObjectId('670adfd11d6415c0d0a94189'),
#  ObjectId('670adfd11d6415c0d0a9418a'),
#  ObjectId('670adfd11d6415c0d0a9418b'),
#  ObjectId('670adfd11d6415c0d0a9418c'),
#  ObjectId('670adfd11d6415c0d0a9418d'),
#  ObjectId('670adfd11d6415c0d0a9418e'),
#  ObjectId('670adfd11d6415c0d0a9418f'),
#  ObjectId('670adfd11d6415c0d0a94190'),
#  ObjectId('670adfd11d6415c0d0a94191'),
#  ObjectId('670adfd11d6415c0d0a94192'),
#  ObjectId('670adfd11d6415c0d0a94193'),
#  ObjectId('670adfd11d6415c0d0a94194'),
#  ObjectId('670adfd11d6415c0d0a94195'),
#  ObjectId('670adfd11d6415c0d0a94196'),
#  ObjectId('670adfd11d6415c0d0a94197'),
#  ObjectId('670adfd11d6415c0d0a94198'),
#  ObjectId('670adfd11d6415c0d0a94199'),
#  ObjectId('670adfd11d6415c0d0a9419a'),
#  ObjectId('670adfd11d6415c0d0a9419b'),
#  ObjectId('670adfd11d6415c0d0a9419c'),
#  ObjectId('670adfd11d6415c0d0a9419d'),
#  ObjectId('670adfd11d6415c0d0a9419e'),
#  ObjectId('670adfd11d6415c0d0a9419f'),
#  ObjectId('670adfd11d6415c0d0a941a0'),
#  ObjectId('670adfd11d6415c0d0a941a1'),
#  ObjectId('670adfd11d6415c0d0a941a2'),
#  ObjectId('670adfd11d6415c0d0a941a3'),
#  ObjectId('670adfd11d6415c0d0a941a4'),
#  ObjectId('670adfd11d6415c0d0a941a5'),
#  ObjectId('670adfd11d6415c0d0a941a6'),
#  ObjectId('670adfd11d6415c0d0a941a7'),
#  ObjectId('670adfd11d6415c0d0a941a8'),
#  ObjectId('670adfd11d6415c0d0a941a9'),
#  ObjectId('670adfd11d6415c0d0a941aa'),
#  ObjectId('670adfd11d6415c0d0a941ab'),
#  ObjectId('670adfd11d6415c0d0a941ac'),
#  ObjectId('670adfd11d6415c0d0a941ad'),
#  ObjectId('670adfd11d6415c0d0a941ae'),
#  ObjectId('670adfd11d6415c0d0a941af'),
#  ObjectId('670adfd11d6415c0d0a941b0'),
#  ObjectId('670adfd11d6415c0d0a941b1'),
#  ObjectId('670adfd11d6415c0d0a941b2'),
#  ObjectId('670adfd11d6415c0d0a941b3'),
#  ObjectId('670adfd11d6415c0d0a941b4'),
#  ObjectId('670adfd11d6415c0d0a941b5'),
#  ObjectId('670adfd11d6415c0d0a941b6'),
#  ObjectId('670adfd11d6415c0d0a941b7'),
#  ObjectId('670adfd11d6415c0d0a941b8'),
#  ObjectId('670adfd11d6415c0d0a941b9'),
#  ObjectId('670adfd11d6415c0d0a941ba'),
#  ObjectId('670adfd11d6415c0d0a941bb'),
#  ObjectId('670adfd11d6415c0d0a941bc'),
#  ObjectId('670adfd11d6415c0d0a941bd'),
#  ObjectId('670adfd11d6415c0d0a941be'),
#  ObjectId('670adfd11d6415c0d0a941bf'),
#  ObjectId('670adfd11d6415c0d0a941c0'),
#  ObjectId('670adfd11d6415c0d0a941c1'),
#  ObjectId('670adfd11d6415c0d0a941c2'),
#  ObjectId('670adfd11d6415c0d0a941c3'),
#  ObjectId('670adfd11d6415c0d0a941c4'),
#  ObjectId('670adfd11d6415c0d0a941c5'),
#  ObjectId('670adfd11d6415c0d0a941c6'),
#  ObjectId('670adfd11d6415c0d0a941c7'),
#  ObjectId('670adfd11d6415c0d0a941c8'),
#  ObjectId('670adfd11d6415c0d0a941c9'),
#  ObjectId('670adfd11d6415c0d0a941ca'),
#  ObjectId('670adfd11d6415c0d0a941cb'),
#  ObjectId('670adfd11d6415c0d0a941cc'),
#  ObjectId('670adfd11d6415c0d0a941cd'),
#  ObjectId('670adfd11d6415c0d0a941ce'),
#  ObjectId('670adfd11d6415c0d0a941cf'),
#  ObjectId('670adfd11d6415c0d0a941d0'),
#  ObjectId('670adfd11d6415c0d0a941d1'),
#  ObjectId('670adfd11d6415c0d0a941d2'),
#  ObjectId('670adfd11d6415c0d0a941d3'),
#  ObjectId('670adfd11d6415c0d0a941d4'),
#  ObjectId('670adfd11d6415c0d0a941d5'),
#  ObjectId('670adfd11d6415c0d0a941d6'),
#  ObjectId('670adfd11d6415c0d0a941d7'),
#  ObjectId('670adfd11d6415c0d0a941d8'),
#  ObjectId('670adfd11d6415c0d0a941d9'),
#  ObjectId('670adfd11d6415c0d0a941da'),
#  ObjectId('670adfd11d6415c0d0a941db'),
#  ObjectId('670adfd11d6415c0d0a941dc'),
#  ObjectId('670adfd11d6415c0d0a941dd'),
#  ObjectId('670adfd11d6415c0d0a941de'),
#  ObjectId('670adfd11d6415c0d0a941df'),
#  ObjectId('670adfd11d6415c0d0a941e0'),
#  ObjectId('670adfd11d6415c0d0a941e1'),
#  ObjectId('670adfd11d6415c0d0a941e2'),
#  ObjectId('670adfd11d6415c0d0a941e3'),
#  ObjectId('670adfd11d6415c0d0a941e4'),
#  ObjectId('670adfd11d6415c0d0a941e5'),
#  ObjectId('670adfd11d6415c0d0a941e6'),
#  ObjectId('670adfd11d6415c0d0a941e7'),
#  ObjectId('670adfd11d6415c0d0a941e8'),
#  ObjectId('670adfd11d6415c0d0a941e9'),
#  ObjectId('670adfd11d6415c0d0a941ea'),
#  ObjectId('670adfd11d6415c0d0a941eb'),
#  ObjectId('670adfd11d6415c0d0a941ec'),
#  ObjectId('670adfd11d6415c0d0a941ed'),
#  ObjectId('670adfd11d6415c0d0a941ee'),
#  ObjectId('670adfd11d6415c0d0a941ef'),
#  ObjectId('670adfd11d6415c0d0a941f0'),
#  ObjectId('670adfd11d6415c0d0a941f1'),
#  ObjectId('670adfd11d6415c0d0a941f2'),
#  ObjectId('670adfd11d6415c0d0a941f3'),
#  ObjectId('670adfd11d6415c0d0a941f4'),
#  ObjectId('670adfd11d6415c0d0a941f5'),
#  ObjectId('670adfd11d6415c0d0a941f6'),
#  ObjectId('670adfd11d6415c0d0a941f7'),
#  ObjectId('670adfd11d6415c0d0a941f8'),
#  ObjectId('670adfd11d6415c0d0a941f9'),
#  ObjectId('670adfd11d6415c0d0a941fa'),
#  ObjectId('670adfd11d6415c0d0a941fb'),
#  ObjectId('670adfd11d6415c0d0a941fc'),
#  ObjectId('670adfd11d6415c0d0a941fd'),
#  ObjectId('670adfd11d6415c0d0a941fe'),
#  ObjectId('670adfd11d6415c0d0a941ff'),
#  ObjectId('670adfd11d6415c0d0a94200'),
#  ObjectId('670adfd11d6415c0d0a94201'),
#  ObjectId('670adfd11d6415c0d0a94202'),
#  ObjectId('670adfd11d6415c0d0a94203'),
#  ObjectId('670adfd11d6415c0d0a94204'),
#  ObjectId('670adfd11d6415c0d0a94205'),
#  ObjectId('670adfd11d6415c0d0a94206'),
#  ObjectId('670adfd11d6415c0d0a94207'),
#  ObjectId('670adfd11d6415c0d0a94208'),
#  ObjectId('670adfd11d6415c0d0a94209'),
#  ObjectId('670adfd11d6415c0d0a9420a'),
#  ObjectId('670adfd11d6415c0d0a9420b'),
#  ObjectId('670adfd11d6415c0d0a9420c'),
#  ObjectId('670adfd11d6415c0d0a9420d'),
#  ObjectId('670adfd11d6415c0d0a9420e'),
#  ObjectId('670adfd11d6415c0d0a9420f'),
#  ObjectId('670adfd11d6415c0d0a94210'),
#  ObjectId('670adfd11d6415c0d0a94211'),
#  ObjectId('670adfd11d6415c0d0a94212'),
#  ObjectId('670adfd11d6415c0d0a94213'),
#  ObjectId('670adfd11d6415c0d0a94214'),
#  ObjectId('670adfd11d6415c0d0a94215'),
#  ObjectId('670adfd11d6415c0d0a94216'),
#  ObjectId('670adfd11d6415c0d0a94217'),
#  ObjectId('670adfd11d6415c0d0a94218'),
#  ObjectId('670adfd11d6415c0d0a94219'),
#  ObjectId('670adfd11d6415c0d0a9421a'),
#  ObjectId('670adfd11d6415c0d0a9421b'),
#  ObjectId('670adfd11d6415c0d0a9421c'),
#  ObjectId('670adfd11d6415c0d0a9421d'),
#  ObjectId('670adfd11d6415c0d0a9421e'),
#  ObjectId('670adfd11d6415c0d0a9421f'),
#  ObjectId('670adfd11d6415c0d0a94220'),
#  ObjectId('670adfd11d6415c0d0a94221'),
#  ObjectId('670adfd11d6415c0d0a94222'),
#  ObjectId('670adfd11d6415c0d0a94223'),
#  ObjectId('670adfd11d6415c0d0a94224'),
#  ObjectId('670adfd11d6415c0d0a94225'),
#  ObjectId('670adfd11d6415c0d0a94226'),
#  ObjectId('670adfd11d6415c0d0a94227'),
#  ObjectId('670adfd11d6415c0d0a94228'),
#  ObjectId('670adfd11d6415c0d0a94229'),
#  ObjectId('670adfd11d6415c0d0a9422a'),
#  ObjectId('670adfd11d6415c0d0a9422b'),
#  ObjectId('670adfd11d6415c0d0a9422c'),
#  ObjectId('670adfd11d6415c0d0a9422d'),
#  ObjectId('670adfd11d6415c0d0a9422e'),
#  ObjectId('670adfd11d6415c0d0a9422f'),
#  ObjectId('670adfd11d6415c0d0a94230'),
#  ObjectId('670adfd11d6415c0d0a94231'),
#  ObjectId('670adfd11d6415c0d0a94232'),
#  ObjectId('670adfd11d6415c0d0a94233'),
#  ObjectId('670adfd11d6415c0d0a94234'),
#  ObjectId('670adfd11d6415c0d0a94235'),
#  ObjectId('670adfd11d6415c0d0a94236'),
#  ObjectId('670adfd11d6415c0d0a94237'),
#  ObjectId('670adfd11d6415c0d0a94238'),
#  ObjectId('670adfd11d6415c0d0a94239'),
#  ObjectId('670adfd11d6415c0d0a9423a'),
#  ObjectId('670adfd11d6415c0d0a9423b'),
#  ObjectId('670adfd11d6415c0d0a9423c'),
#  ObjectId('670adfd11d6415c0d0a9423d'),
#  ObjectId('670adfd11d6415c0d0a9423e'),
#  ObjectId('670adfd11d6415c0d0a9423f'),
#  ObjectId('670adfd11d6415c0d0a94240'),
#  ObjectId('670adfd11d6415c0d0a94241'),
#  ObjectId('670adfd11d6415c0d0a94242'),
#  ObjectId('670adfd11d6415c0d0a94243'),
#  ObjectId('670adfd11d6415c0d0a94244'),
#  ObjectId('670adfd11d6415c0d0a94245'),
#  ObjectId('670adfd11d6415c0d0a94246'),
#  ObjectId('670adfd11d6415c0d0a94247'),
#  ObjectId('670adfd11d6415c0d0a94248'),
#  ObjectId('670adfd11d6415c0d0a94249'),
#  ObjectId('670adfd11d6415c0d0a9424a'),
#  ObjectId('670adfd11d6415c0d0a9424b'),
#  ObjectId('670adfd11d6415c0d0a9424c'),
#  ObjectId('670adfd11d6415c0d0a9424d'),
#  ObjectId('670adfd11d6415c0d0a9424e'),
#  ObjectId('670adfd11d6415c0d0a9424f'),
#  ObjectId('670adfd11d6415c0d0a94250'),
#  ObjectId('670adfd11d6415c0d0a94251'),
#  ObjectId('670adfd11d6415c0d0a94252'),
#  ObjectId('670adfd11d6415c0d0a94253'),
#  ObjectId('670adfd11d6415c0d0a94254'),
#  ObjectId('670adfd11d6415c0d0a94255'),
#  ObjectId('670adfd11d6415c0d0a94256'),
#  ObjectId('670adfd11d6415c0d0a94257'),
#  ObjectId('670adfd11d6415c0d0a94258'),
#  ObjectId('670adfd11d6415c0d0a94259'),
#  ObjectId('670adfd11d6415c0d0a9425a'),
#  ObjectId('670adfd11d6415c0d0a9425b'),
#  ObjectId('670adfd11d6415c0d0a9425c'),
#  ObjectId('670adfd11d6415c0d0a9425d'),
#  ObjectId('670adfd11d6415c0d0a9425e'),
#  ObjectId('670adfd11d6415c0d0a9425f'),
#  ObjectId('670adfd11d6415c0d0a94260'),
#  ObjectId('670adfd11d6415c0d0a94261'),
#  ObjectId('670adfd11d6415c0d0a94262'),
#  ObjectId('670adfd11d6415c0d0a94263'),
#  ObjectId('670adfd11d6415c0d0a94264'),
#  ObjectId('670adfd11d6415c0d0a94265'),
#  ObjectId('670adfd11d6415c0d0a94266'),
#  ObjectId('670adfd11d6415c0d0a94267'),
#  ObjectId('670adfd11d6415c0d0a94268'),
#  ObjectId('670adfd11d6415c0d0a94269'),
#  ObjectId('670adfd11d6415c0d0a9426a'),
#  ObjectId('670adfd11d6415c0d0a9426b'),
#  ObjectId('670adfd11d6415c0d0a9426c'),
#  ObjectId('670adfd11d6415c0d0a9426d'),
#  ObjectId('670adfd11d6415c0d0a9426e'),
#  ObjectId('670adfd11d6415c0d0a9426f'),
#  ObjectId('670adfd11d6415c0d0a94270'),
#  ObjectId('670adfd11d6415c0d0a94271'),
#  ObjectId('670adfd11d6415c0d0a94272'),
#  ObjectId('670adfd11d6415c0d0a94273'),
#  ObjectId('670adfd11d6415c0d0a94274'),
#  ObjectId('670adfd11d6415c0d0a94275'),
#  ObjectId('670adfd11d6415c0d0a94276'),
#  ObjectId('670adfd11d6415c0d0a94277'),
#  ObjectId('670adfd11d6415c0d0a94278'),
#  ObjectId('670adfd11d6415c0d0a94279'),
#  ObjectId('670adfd11d6415c0d0a9427a'),
#  ObjectId('670adfd11d6415c0d0a9427b'),
#  ObjectId('670adfd11d6415c0d0a9427c'),
#  ObjectId('670adfd11d6415c0d0a9427d'),
#  ObjectId('670adfd11d6415c0d0a9427e'),
#  ObjectId('670adfd11d6415c0d0a9427f'),
#  ObjectId('670adfd11d6415c0d0a94280'),
#  ObjectId('670adfd11d6415c0d0a94281'),
#  ObjectId('670adfd11d6415c0d0a94282'),
#  ObjectId('670adfd11d6415c0d0a94283'),
#  ObjectId('670adfd11d6415c0d0a94284'),
#  ObjectId('670adfd11d6415c0d0a94285'),
#  ObjectId('670adfd11d6415c0d0a94286'),
#  ObjectId('670adfd11d6415c0d0a94287'),
#  ObjectId('670adfd11d6415c0d0a94288'),
#  ObjectId('670adfd11d6415c0d0a94289'),
#  ObjectId('670adfd11d6415c0d0a9428a'),
#  ObjectId('670adfd11d6415c0d0a9428b'),
#  ObjectId('670adfd11d6415c0d0a9428c'),
#  ObjectId('670adfd11d6415c0d0a9428d'),
#  ObjectId('670adfd11d6415c0d0a9428e'),
#  ObjectId('670adfd11d6415c0d0a9428f'),
#  ObjectId('670adfd11d6415c0d0a94290'),
#  ObjectId('670adfd11d6415c0d0a94291'),
#  ObjectId('670adfd11d6415c0d0a94292'),
#  ObjectId('670adfd11d6415c0d0a94293'),
#  ObjectId('670adfd11d6415c0d0a94294'),
#  ObjectId('670adfd11d6415c0d0a94295'),
#  ObjectId('670adfd11d6415c0d0a94296'),
#  ObjectId('670adfd11d6415c0d0a94297'),
#  ObjectId('670adfd11d6415c0d0a94298'),
#  ObjectId('670adfd11d6415c0d0a94299'),
#  ObjectId('670adfd11d6415c0d0a9429a'),
#  ObjectId('670adfd11d6415c0d0a9429b'),
#  ObjectId('670adfd11d6415c0d0a9429c'),
#  ObjectId('670adfd11d6415c0d0a9429d'),
#  ObjectId('670adfd11d6415c0d0a9429e'),
#  ObjectId('670adfd11d6415c0d0a9429f'),
#  ObjectId('670adfd11d6415c0d0a942a0'),
#  ObjectId('670adfd11d6415c0d0a942a1'),
#  ObjectId('670adfd11d6415c0d0a942a2'),
#  ObjectId('670adfd11d6415c0d0a942a3'),
#  ObjectId('670adfd11d6415c0d0a942a4'),
#  ObjectId('670adfd11d6415c0d0a942a5'),
#  ObjectId('670adfd11d6415c0d0a942a6'),
#  ObjectId('670adfd11d6415c0d0a942a7'),
#  ObjectId('670adfd11d6415c0d0a942a8'),
#  ObjectId('670adfd11d6415c0d0a942a9'),
#  ObjectId('670adfd11d6415c0d0a942aa'),
#  ObjectId('670adfd11d6415c0d0a942ab'),
#  ObjectId('670adfd11d6415c0d0a942ac'),
#  ObjectId('670adfd11d6415c0d0a942ad'),
#  ObjectId('670adfd11d6415c0d0a942ae'),
#  ObjectId('670adfd11d6415c0d0a942af'),
#  ObjectId('670adfd11d6415c0d0a942b0'),
#  ObjectId('670adfd11d6415c0d0a942b1'),
#  ObjectId('670adfd11d6415c0d0a942b2'),
#  ObjectId('670adfd11d6415c0d0a942b3'),
#  ObjectId('670adfd11d6415c0d0a942b4'),
#  ObjectId('670adfd11d6415c0d0a942b5'),
#  ObjectId('670adfd11d6415c0d0a942b6'),
#  ObjectId('670adfd11d6415c0d0a942b7'),
#  ObjectId('670adfd11d6415c0d0a942b8'),
#  ObjectId('670adfd11d6415c0d0a942b9'),
#  ObjectId('670adfd11d6415c0d0a942ba'),
#  ObjectId('670adfd11d6415c0d0a942bb'),
#  ObjectId('670adfd11d6415c0d0a942bc'),
#  ObjectId('670adfd11d6415c0d0a942bd'),
#  ObjectId('670adfd11d6415c0d0a942be'),
#  ObjectId('670adfd11d6415c0d0a942bf'),
#  ObjectId('670adfd11d6415c0d0a942c0'),
#  ObjectId('670adfd11d6415c0d0a942c1'),
#  ObjectId('670adfd11d6415c0d0a942c2'),
#  ObjectId('670adfd11d6415c0d0a942c3'),
#  ObjectId('670adfd11d6415c0d0a942c4'),
#  ObjectId('670adfd11d6415c0d0a942c5'),
#  ObjectId('670adfd11d6415c0d0a942c6'),
#  ObjectId('670adfd11d6415c0d0a942c7'),
#  ObjectId('670adfd11d6415c0d0a942c8'),
#  ObjectId('670adfd11d6415c0d0a942c9'),
#  ObjectId('670adfd11d6415c0d0a942ca'),
#  ObjectId('670adfd11d6415c0d0a942cb'),
#  ObjectId('670adfd11d6415c0d0a942cc'),
#  ObjectId('670adfd11d6415c0d0a942cd'),
#  ObjectId('670adfd11d6415c0d0a942ce'),
#  ObjectId('670adfd11d6415c0d0a942cf'),
#  ObjectId('670adfd11d6415c0d0a942d0'),
#  ObjectId('670adfd11d6415c0d0a942d1'),
#  ObjectId('670adfd11d6415c0d0a942d2'),
#  ObjectId('670adfd11d6415c0d0a942d3'),
#  ObjectId('670adfd11d6415c0d0a942d4'),
#  ObjectId('670adfd11d6415c0d0a942d5'),
#  ObjectId('670adfd11d6415c0d0a942d6'),
#  ObjectId('670adfd11d6415c0d0a942d7'),
#  ObjectId('670adfd11d6415c0d0a942d8'),
#  ObjectId('670adfd11d6415c0d0a942d9'),
#  ObjectId('670adfd11d6415c0d0a942da'),
#  ObjectId('670adfd11d6415c0d0a942db'),
#  ObjectId('670adfd11d6415c0d0a942dc'),
#  ObjectId('670adfd11d6415c0d0a942dd'),
#  ObjectId('670adfd11d6415c0d0a942de'),
#  ObjectId('670adfd11d6415c0d0a942df'),
#  ObjectId('670adfd11d6415c0d0a942e0'),
#  ObjectId('670adfd11d6415c0d0a942e1'),
#  ObjectId('670adfd11d6415c0d0a942e2'),
#  ObjectId('670adfd11d6415c0d0a942e3'),
#  ObjectId('670adfd11d6415c0d0a942e4'),
#  ObjectId('670adfd11d6415c0d0a942e5'),
#  ObjectId('670adfd11d6415c0d0a942e6'),
#  ObjectId('670adfd11d6415c0d0a942e7'),
#  ObjectId('670adfd11d6415c0d0a942e8'),
#  ObjectId('670adfd11d6415c0d0a942e9'),
#  ObjectId('670adfd11d6415c0d0a942ea'),
#  ObjectId('670adfd11d6415c0d0a942eb'),
#  ObjectId('670adfd11d6415c0d0a942ec'),
#  ObjectId('670adfd11d6415c0d0a942ed'),
#  ObjectId('670adfd11d6415c0d0a942ee'),
#  ObjectId('670adfd11d6415c0d0a942ef'),
#  ObjectId('670adfd11d6415c0d0a942f0'),
#  ObjectId('670adfd11d6415c0d0a942f1'),
#  ObjectId('670adfd11d6415c0d0a942f2'),
#  ObjectId('670adfd11d6415c0d0a942f3'),
#  ObjectId('670adfd11d6415c0d0a942f4'),
#  ObjectId('670adfd11d6415c0d0a942f5'),
#  ObjectId('670adfd11d6415c0d0a942f6'),
#  ObjectId('670adfd11d6415c0d0a942f7'),
#  ObjectId('670adfd11d6415c0d0a942f8'),
#  ObjectId('670adfd11d6415c0d0a942f9'),
#  ObjectId('670adfd11d6415c0d0a942fa'),
#  ObjectId('670adfd11d6415c0d0a942fb'),
#  ObjectId('670adfd11d6415c0d0a942fc'),
#  ObjectId('670adfd11d6415c0d0a942fd'),
#  ObjectId('670adfd11d6415c0d0a942fe'),
#  ObjectId('670adfd11d6415c0d0a942ff'),
#  ObjectId('670adfd11d6415c0d0a94300'),
#  ObjectId('670adfd11d6415c0d0a94301'),
#  ObjectId('670adfd11d6415c0d0a94302'),
#  ObjectId('670adfd11d6415c0d0a94303'),
#  ObjectId('670adfd11d6415c0d0a94304'),
#  ObjectId('670adfd11d6415c0d0a94305'),
#  ObjectId('670adfd11d6415c0d0a94306'),
#  ObjectId('670adfd11d6415c0d0a94307'),
#  ObjectId('670adfd11d6415c0d0a94308'),
#  ObjectId('670adfd11d6415c0d0a94309'),
#  ObjectId('670adfd11d6415c0d0a9430a'),
#  ObjectId('670adfd11d6415c0d0a9430b'),
#  ObjectId('670adfd11d6415c0d0a9430c'),
#  ObjectId('670adfd11d6415c0d0a9430d'),
#  ObjectId('670adfd11d6415c0d0a9430e'),
#  ObjectId('670adfd11d6415c0d0a9430f'),
#  ObjectId('670adfd11d6415c0d0a94310'),
#  ObjectId('670adfd11d6415c0d0a94311'),
#  ObjectId('670adfd11d6415c0d0a94312'),
#  ObjectId('670adfd11d6415c0d0a94313'),
#  ObjectId('670adfd11d6415c0d0a94314'),
#  ObjectId('670adfd11d6415c0d0a94315'),
#  ObjectId('670adfd11d6415c0d0a94316'),
#  ObjectId('670adfd11d6415c0d0a94317'),
#  ObjectId('670adfd11d6415c0d0a94318'),
#  ObjectId('670adfd11d6415c0d0a94319'),
#  ObjectId('670adfd11d6415c0d0a9431a'),
#  ObjectId('670adfd11d6415c0d0a9431b'),
#  ObjectId('670adfd11d6415c0d0a9431c'),
#  ObjectId('670adfd11d6415c0d0a9431d'),
#  ObjectId('670adfd11d6415c0d0a9431e'),
#  ObjectId('670adfd11d6415c0d0a9431f'),
#  ObjectId('670adfd11d6415c0d0a94320'),
#  ObjectId('670adfd11d6415c0d0a94321'),
#  ObjectId('670adfd11d6415c0d0a94322'),
#  ObjectId('670adfd11d6415c0d0a94323'),
#  ObjectId('670adfd11d6415c0d0a94324'),
#  ObjectId('670adfd11d6415c0d0a94325'),
#  ObjectId('670adfd11d6415c0d0a94326'),
#  ObjectId('670adfd11d6415c0d0a94327'),
#  ObjectId('670adfd11d6415c0d0a94328'),
#  ObjectId('670adfd11d6415c0d0a94329'),
#  ObjectId('670adfd11d6415c0d0a9432a'),
#  ObjectId('670adfd11d6415c0d0a9432b'),
#  ObjectId('670adfd11d6415c0d0a9432c'),
#  ObjectId('670adfd11d6415c0d0a9432d'),
#  ObjectId('670adfd11d6415c0d0a9432e'),
#  ObjectId('670adfd11d6415c0d0a9432f'),
#  ObjectId('670adfd11d6415c0d0a94330'),
#  ObjectId('670adfd11d6415c0d0a94331'),
#  ObjectId('670adfd11d6415c0d0a94332'),
#  ObjectId('670adfd11d6415c0d0a94333'),
#  ObjectId('670adfd11d6415c0d0a94334'),
#  ObjectId('670adfd11d6415c0d0a94335'),
#  ObjectId('670adfd11d6415c0d0a94336'),
#  ObjectId('670adfd11d6415c0d0a94337'),
#  ObjectId('670adfd11d6415c0d0a94338'),
#  ObjectId('670adfd11d6415c0d0a94339'),
#  ObjectId('670adfd11d6415c0d0a9433a'),
#  ObjectId('670adfd11d6415c0d0a9433b'),
#  ObjectId('670adfd11d6415c0d0a9433c'),
#  ObjectId('670adfd11d6415c0d0a9433d'),
#  ObjectId('670adfd11d6415c0d0a9433e'),
#  ObjectId('670adfd11d6415c0d0a9433f'),
#  ObjectId('670adfd11d6415c0d0a94340'),
#  ObjectId('670adfd11d6415c0d0a94341'),
#  ObjectId('670adfd11d6415c0d0a94342'),
#  ObjectId('670adfd11d6415c0d0a94343'),
#  ObjectId('670adfd11d6415c0d0a94344'),
#  ObjectId('670adfd11d6415c0d0a94345'),
#  ObjectId('670adfd11d6415c0d0a94346'),
#  ObjectId('670adfd11d6415c0d0a94347'),
#  ObjectId('670adfd11d6415c0d0a94348'),
#  ObjectId('670adfd11d6415c0d0a94349'),
#  ObjectId('670adfd11d6415c0d0a9434a'),
#  ObjectId('670adfd11d6415c0d0a9434b'),
#  ObjectId('670adfd11d6415c0d0a9434c'),
#  ObjectId('670adfd11d6415c0d0a9434d'),
#  ObjectId('670adfd11d6415c0d0a9434e'),
#  ObjectId('670adfd11d6415c0d0a9434f'),
#  ObjectId('670adfd11d6415c0d0a94350'),
#  ObjectId('670adfd11d6415c0d0a94351'),
#  ObjectId('670adfd11d6415c0d0a94352'),
#  ObjectId('670adfd11d6415c0d0a94353'),
#  ObjectId('670adfd11d6415c0d0a94354'),
#  ObjectId('670adfd11d6415c0d0a94355'),
#  ObjectId('670adfd11d6415c0d0a94356'),
#  ObjectId('670adfd11d6415c0d0a94357'),
#  ObjectId('670adfd11d6415c0d0a94358'),
#  ObjectId('670adfd11d6415c0d0a94359'),
#  ObjectId('670adfd11d6415c0d0a9435a'),
#  ObjectId('670adfd11d6415c0d0a9435b'),
#  ObjectId('670adfd11d6415c0d0a9435c'),
#  ObjectId('670adfd11d6415c0d0a9435d'),
#  ObjectId('670adfd11d6415c0d0a9435e'),
#  ObjectId('670adfd11d6415c0d0a9435f'),
#  ObjectId('670adfd11d6415c0d0a94360'),
#  ObjectId('670adfd11d6415c0d0a94361'),
#  ObjectId('670adfd11d6415c0d0a94362'),
#  ObjectId('670adfd11d6415c0d0a94363'),
#  ObjectId('670adfd11d6415c0d0a94364'),
#  ObjectId('670adfd11d6415c0d0a94365'),
#  ObjectId('670adfd11d6415c0d0a94366'),
#  ObjectId('670adfd11d6415c0d0a94367'),
#  ObjectId('670adfd11d6415c0d0a94368'),
#  ObjectId('670adfd11d6415c0d0a94369'),
#  ObjectId('670adfd11d6415c0d0a9436a'),
#  ObjectId('670adfd11d6415c0d0a9436b'),
#  ObjectId('670adfd11d6415c0d0a9436c'),
#  ObjectId('670adfd11d6415c0d0a9436d'),
#  ObjectId('670adfd11d6415c0d0a9436e'),
#  ObjectId('670adfd11d6415c0d0a9436f'),
#  ObjectId('670adfd11d6415c0d0a94370'),
#  ObjectId('670adfd11d6415c0d0a94371'),
#  ObjectId('670adfd11d6415c0d0a94372'),
#  ObjectId('670adfd11d6415c0d0a94373'),
#  ObjectId('670adfd11d6415c0d0a94374'),
#  ObjectId('670adfd11d6415c0d0a94375'),
#  ObjectId('670adfd11d6415c0d0a94376'),
#  ObjectId('670adfd11d6415c0d0a94377'),
#  ObjectId('670adfd11d6415c0d0a94378'),
#  ObjectId('670adfd11d6415c0d0a94379'),
#  ObjectId('670adfd11d6415c0d0a9437a'),
#  ObjectId('670adfd11d6415c0d0a9437b'),
#  ObjectId('670adfd11d6415c0d0a9437c'),
#  ObjectId('670adfd11d6415c0d0a9437d'),
#  ObjectId('670adfd11d6415c0d0a9437e'),
#  ObjectId('670adfd11d6415c0d0a9437f'),
#  ObjectId('670adfd11d6415c0d0a94380'),
#  ObjectId('670adfd11d6415c0d0a94381'),
#  ObjectId('670adfd11d6415c0d0a94382'),
#  ObjectId('670adfd11d6415c0d0a94383'),
#  ObjectId('670adfd11d6415c0d0a94384'),
#  ObjectId('670adfd11d6415c0d0a94385'),
#  ObjectId('670adfd11d6415c0d0a94386'),
#  ObjectId('670adfd11d6415c0d0a94387'),
#  ObjectId('670adfd11d6415c0d0a94388'),
#  ObjectId('670adfd11d6415c0d0a94389'),
#  ObjectId('670adfd11d6415c0d0a9438a'),
#  ObjectId('670adfd11d6415c0d0a9438b'),
#  ObjectId('670adfd11d6415c0d0a9438c'),
#  ObjectId('670adfd11d6415c0d0a9438d'),
#  ObjectId('670adfd11d6415c0d0a9438e'),
#  ObjectId('670adfd11d6415c0d0a9438f'),
#  ObjectId('670adfd11d6415c0d0a94390'),
#  ObjectId('670adfd11d6415c0d0a94391'),
#  ObjectId('670adfd11d6415c0d0a94392'),
#  ObjectId('670adfd11d6415c0d0a94393'),
#  ObjectId('670adfd11d6415c0d0a94394'),
#  ObjectId('670adfd11d6415c0d0a94395'),
#  ObjectId('670adfd11d6415c0d0a94396'),
#  ObjectId('670adfd11d6415c0d0a94397'),
#  ObjectId('670adfd11d6415c0d0a94398'),
#  ObjectId('670adfd11d6415c0d0a94399'),
#  ObjectId('670adfd11d6415c0d0a9439a'),
#  ObjectId('670adfd11d6415c0d0a9439b'),
#  ObjectId('670adfd11d6415c0d0a9439c'),
#  ObjectId('670adfd11d6415c0d0a9439d'),
#  ObjectId('670adfd11d6415c0d0a9439e'),
#  ObjectId('670adfd11d6415c0d0a9439f'),
#  ObjectId('670adfd11d6415c0d0a943a0'),
#  ObjectId('670adfd11d6415c0d0a943a1'),
#  ObjectId('670adfd11d6415c0d0a943a2'),
#  ObjectId('670adfd11d6415c0d0a943a3'),
#  ObjectId('670adfd11d6415c0d0a943a4'),
#  ObjectId('670adfd11d6415c0d0a943a5'),
#  ObjectId('670adfd11d6415c0d0a943a6'),
#  ObjectId('670adfd11d6415c0d0a943a7'),
#  ObjectId('670adfd11d6415c0d0a943a8'),
#  ObjectId('670adfd11d6415c0d0a943a9'),
#  ObjectId('670adfd11d6415c0d0a943aa'),
#  ObjectId('670adfd11d6415c0d0a943ab'),
#  ObjectId('670adfd11d6415c0d0a943ac'),
#  ObjectId('670adfd11d6415c0d0a943ad'),
#  ObjectId('670adfd11d6415c0d0a943ae'),
#  ObjectId('670adfd11d6415c0d0a943af'),
#  ObjectId('670adfd11d6415c0d0a943b0'),
#  ObjectId('670adfd11d6415c0d0a943b1'),
#  ObjectId('670adfd11d6415c0d0a943b2'),
#  ObjectId('670adfd11d6415c0d0a943b3'),
#  ObjectId('670adfd11d6415c0d0a943b4'),
#  ObjectId('670adfd11d6415c0d0a943b5'),
#  ObjectId('670adfd11d6415c0d0a943b6'),
#  ObjectId('670adfd11d6415c0d0a943b7'),
#  ObjectId('670adfd11d6415c0d0a943b8'),
#  ObjectId('670adfd11d6415c0d0a943b9'),
#  ObjectId('670adfd11d6415c0d0a943ba'),
#  ObjectId('670adfd11d6415c0d0a943bb'),
#  ObjectId('670adfd11d6415c0d0a943bc'),
#  ObjectId('670adfd11d6415c0d0a943bd'),
#  ObjectId('670adfd11d6415c0d0a943be'),
#  ObjectId('670adfd11d6415c0d0a943bf'),
#  ObjectId('670adfd11d6415c0d0a943c0'),
#  ObjectId('670adfd11d6415c0d0a943c1'),
#  ObjectId('670adfd11d6415c0d0a943c2'),
#  ObjectId('670adfd11d6415c0d0a943c3'),
#  ObjectId('670adfd11d6415c0d0a943c4'),
#  ObjectId('670adfd11d6415c0d0a943c5'),
#  ObjectId('670adfd11d6415c0d0a943c6'),
#  ObjectId('670adfd11d6415c0d0a943c7'),
#  ObjectId('670adfd11d6415c0d0a943c8'),
#  ObjectId('670adfd11d6415c0d0a943c9'),
#  ObjectId('670adfd11d6415c0d0a943ca'),
#  ObjectId('670adfd11d6415c0d0a943cb'),
#  ObjectId('670adfd11d6415c0d0a943cc'),
#  ObjectId('670adfd11d6415c0d0a943cd'),
#  ObjectId('670adfd11d6415c0d0a943ce'),
#  ObjectId('670adfd11d6415c0d0a943cf'),
#  ObjectId('670adfd11d6415c0d0a943d0'),
#  ObjectId('670adfd11d6415c0d0a943d1'),
#  ObjectId('670adfd11d6415c0d0a943d2'),
#  ObjectId('670adfd11d6415c0d0a943d3'),
#  ObjectId('670adfd11d6415c0d0a943d4'),
#  ObjectId('670adfd11d6415c0d0a943d5'),
#  ObjectId('670adfd11d6415c0d0a943d6'),
#  ObjectId('670adfd11d6415c0d0a943d7'),
#  ObjectId('670adfd11d6415c0d0a943d8'),
#  ObjectId('670adfd11d6415c0d0a943d9'),
#  ObjectId('670adfd11d6415c0d0a943da'),
#  ObjectId('670adfd11d6415c0d0a943db'),
#  ObjectId('670adfd11d6415c0d0a943dc'),
#  ObjectId('670adfd11d6415c0d0a943dd'),
#  ObjectId('670adfd11d6415c0d0a943de'),
#  ObjectId('670adfd11d6415c0d0a943df'),
#  ObjectId('670adfd11d6415c0d0a943e0'),
#  ObjectId('670adfd11d6415c0d0a943e1'),
#  ObjectId('670adfd11d6415c0d0a943e2'),
#  ObjectId('670adfd11d6415c0d0a943e3'),
#  ObjectId('670adfd11d6415c0d0a943e4'),
#  ObjectId('670adfd11d6415c0d0a943e5'),
#  ObjectId('670adfd11d6415c0d0a943e6'),
#  ObjectId('670adfd11d6415c0d0a943e7'),
#  ObjectId('670adfd11d6415c0d0a943e8'),
#  ObjectId('670adfd11d6415c0d0a943e9'),
#  ObjectId('670adfd11d6415c0d0a943ea'),
#  ObjectId('670adfd11d6415c0d0a943eb'),
#  ObjectId('670adfd11d6415c0d0a943ec'),
#  ObjectId('670adfd11d6415c0d0a943ed'),
#  ObjectId('670adfd11d6415c0d0a943ee'),
#  ObjectId('670adfd11d6415c0d0a943ef'),
#  ObjectId('670adfd11d6415c0d0a943f0'),
#  ObjectId('670adfd11d6415c0d0a943f1'),
#  ObjectId('670adfd11d6415c0d0a943f2'),
#  ObjectId('670adfd11d6415c0d0a943f3'),
#  ObjectId('670adfd11d6415c0d0a943f4'),
#  ObjectId('670adfd11d6415c0d0a943f5'),
#  ObjectId('670adfd11d6415c0d0a943f6'),
#  ObjectId('670adfd11d6415c0d0a943f7'),
#  ObjectId('670adfd11d6415c0d0a943f8'),
#  ObjectId('670adfd11d6415c0d0a943f9'),
#  ObjectId('670adfd11d6415c0d0a943fa'),
#  ObjectId('670adfd11d6415c0d0a943fb'),
#  ObjectId('670adfd11d6415c0d0a943fc'),
#  ObjectId('670adfd11d6415c0d0a943fd'),
#  ObjectId('670adfd11d6415c0d0a943fe'),
#  ObjectId('670adfd11d6415c0d0a943ff'),
#  ObjectId('670adfd11d6415c0d0a94400'),
#  ObjectId('670adfd11d6415c0d0a94401'),
#  ObjectId('670adfd11d6415c0d0a94402'),
#  ObjectId('670adfd11d6415c0d0a94403'),
#  ObjectId('670adfd11d6415c0d0a94404'),
#  ObjectId('670adfd11d6415c0d0a94405'),
#  ObjectId('670adfd11d6415c0d0a94406'),
#  ObjectId('670adfd11d6415c0d0a94407'),
#  ObjectId('670adfd11d6415c0d0a94408'),
#  ObjectId('670adfd11d6415c0d0a94409'),
#  ObjectId('670adfd11d6415c0d0a9440a'),
#  ObjectId('670adfd11d6415c0d0a9440b'),
#  ObjectId('670adfd11d6415c0d0a9440c'),
#  ObjectId('670adfd11d6415c0d0a9440d'),
#  ObjectId('670adfd11d6415c0d0a9440e'),
#  ObjectId('670adfd11d6415c0d0a9440f'),
#  ObjectId('670adfd11d6415c0d0a94410'),
#  ObjectId('670adfd11d6415c0d0a94411'),
#  ObjectId('670adfd11d6415c0d0a94412'),
#  ObjectId('670adfd11d6415c0d0a94413'),
#  ObjectId('670adfd11d6415c0d0a94414'),
#  ObjectId('670adfd11d6415c0d0a94415'),
#  ObjectId('670adfd11d6415c0d0a94416'),
#  ObjectId('670adfd11d6415c0d0a94417'),
#  ObjectId('670adfd11d6415c0d0a94418'),
#  ObjectId('670adfd11d6415c0d0a94419'),
#  ObjectId('670adfd11d6415c0d0a9441a'),
#  ObjectId('670adfd11d6415c0d0a9441b'),
#  ObjectId('670adfd11d6415c0d0a9441c'),
#  ObjectId('670adfd11d6415c0d0a9441d'),
#  ObjectId('670adfd11d6415c0d0a9441e'),
#  ObjectId('670adfd11d6415c0d0a9441f'),
#  ObjectId('670adfd11d6415c0d0a94420'),
#  ObjectId('670adfd11d6415c0d0a94421'),
#  ObjectId('670adfd11d6415c0d0a94422'),
#  ObjectId('670adfd11d6415c0d0a94423'),
#  ObjectId('670adfd11d6415c0d0a94424'),
#  ObjectId('670adfd11d6415c0d0a94425'),
#  ObjectId('670adfd11d6415c0d0a94426'),
#  ObjectId('670adfd11d6415c0d0a94427'),
#  ObjectId('670adfd11d6415c0d0a94428'),
#  ObjectId('670adfd11d6415c0d0a94429'),
#  ObjectId('670adfd11d6415c0d0a9442a'),
#  ObjectId('670adfd11d6415c0d0a9442b'),
#  ObjectId('670adfd11d6415c0d0a9442c'),
#  ObjectId('670adfd11d6415c0d0a9442d'),
#  ObjectId('670adfd11d6415c0d0a9442e'),
#  ObjectId('670adfd11d6415c0d0a9442f'),
#  ObjectId('670adfd11d6415c0d0a94430'),
#  ObjectId('670adfd11d6415c0d0a94431'),
#  ObjectId('670adfd11d6415c0d0a94432'),
#  ObjectId('670adfd11d6415c0d0a94433'),
#  ObjectId('670adfd11d6415c0d0a94434'),
#  ObjectId('670adfd11d6415c0d0a94435'),
#  ObjectId('670adfd11d6415c0d0a94436'),
#  ObjectId('670adfd11d6415c0d0a94437'),
#  ObjectId('670adfd11d6415c0d0a94438'),
#  ObjectId('670adfd11d6415c0d0a94439'),
#  ObjectId('670adfd11d6415c0d0a9443a'),
#  ObjectId('670adfd11d6415c0d0a9443b'),
#  ObjectId('670adfd11d6415c0d0a9443c'),
#  ObjectId('670adfd11d6415c0d0a9443d'),
#  ObjectId('670adfd11d6415c0d0a9443e'),
#  ObjectId('670adfd11d6415c0d0a9443f'),
#  ObjectId('670adfd11d6415c0d0a94440'),
#  ObjectId('670adfd11d6415c0d0a94441'),
#  ObjectId('670adfd11d6415c0d0a94442'),
#  ObjectId('670adfd11d6415c0d0a94443'),
#  ObjectId('670adfd11d6415c0d0a94444'),
#  ObjectId('670adfd11d6415c0d0a94445'),
#  ObjectId('670adfd11d6415c0d0a94446'),
#  ObjectId('670adfd11d6415c0d0a94447'),
#  ObjectId('670adfd11d6415c0d0a94448'),
#  ObjectId('670adfd11d6415c0d0a94449'),
#  ObjectId('670adfd11d6415c0d0a9444a'),
#  ObjectId('670adfd11d6415c0d0a9444b'),
#  ObjectId('670adfd11d6415c0d0a9444c'),
#  ObjectId('670adfd11d6415c0d0a9444d'),
#  ObjectId('670adfd11d6415c0d0a9444e'),
#  ObjectId('670adfd11d6415c0d0a9444f'),
#  ObjectId('670adfd11d6415c0d0a94450'),
#  ObjectId('670adfd11d6415c0d0a94451'),
#  ObjectId('670adfd11d6415c0d0a94452'),
#  ObjectId('670adfd11d6415c0d0a94453'),
#  ObjectId('670adfd11d6415c0d0a94454'),
#  ObjectId('670adfd11d6415c0d0a94455'),
#  ObjectId('670adfd11d6415c0d0a94456'),
#  ObjectId('670adfd11d6415c0d0a94457'),
#  ObjectId('670adfd11d6415c0d0a94458'),
#  ObjectId('670adfd11d6415c0d0a94459'),
#  ObjectId('670adfd11d6415c0d0a9445a'),
#  ObjectId('670adfd11d6415c0d0a9445b'),
#  ObjectId('670adfd11d6415c0d0a9445c'),
#  ObjectId('670adfd11d6415c0d0a9445d'),
#  ObjectId('670adfd11d6415c0d0a9445e'),
#  ObjectId('670adfd11d6415c0d0a9445f'),
#  ObjectId('670adfd11d6415c0d0a94460'),
#  ObjectId('670adfd11d6415c0d0a94461'),
#  ObjectId('670adfd11d6415c0d0a94462'),
#  ObjectId('670adfd11d6415c0d0a94463'),
#  ObjectId('670adfd11d6415c0d0a94464'),
#  ObjectId('670adfd11d6415c0d0a94465'),
#  ObjectId('670adfd11d6415c0d0a94466'),
#  ObjectId('670adfd11d6415c0d0a94467'),
#  ObjectId('670adfd11d6415c0d0a94468'),
#  ObjectId('670adfd11d6415c0d0a94469'),
#  ObjectId('670adfd11d6415c0d0a9446a'),
#  ObjectId('670adfd11d6415c0d0a9446b'),
#  ObjectId('670adfd11d6415c0d0a9446c'),
#  ObjectId('670adfd11d6415c0d0a9446d'),
#  ObjectId('670adfd11d6415c0d0a9446e'),
#  ObjectId('670adfd11d6415c0d0a9446f'),
#  ObjectId('670adfd11d6415c0d0a94470'),
#  ObjectId('670adfd11d6415c0d0a94471'),
#  ObjectId('670adfd11d6415c0d0a94472'),
#  ObjectId('670adfd11d6415c0d0a94473'),
#  ObjectId('670adfd11d6415c0d0a94474'),
#  ObjectId('670adfd11d6415c0d0a94475'),
#  ObjectId('670adfd11d6415c0d0a94476'),
#  ObjectId('670adfd11d6415c0d0a94477'),
#  ObjectId('670adfd11d6415c0d0a94478'),
#  ObjectId('670adfd11d6415c0d0a94479'),
#  ObjectId('670adfd11d6415c0d0a9447a'),
#  ObjectId('670adfd11d6415c0d0a9447b'),
#  ObjectId('670adfd11d6415c0d0a9447c'),
#  ObjectId('670adfd11d6415c0d0a9447d'),
#  ObjectId('670adfd11d6415c0d0a9447e'),
#  ObjectId('670adfd11d6415c0d0a9447f'),
#  ObjectId('670adfd11d6415c0d0a94480'),
#  ObjectId('670adfd11d6415c0d0a94481'),
#  ObjectId('670adfd11d6415c0d0a94482'),
#  ObjectId('670adfd11d6415c0d0a94483'),
#  ObjectId('670adfd11d6415c0d0a94484'),
#  ObjectId('670adfd11d6415c0d0a94485'),
#  ObjectId('670adfd11d6415c0d0a94486'),
#  ObjectId('670adfd11d6415c0d0a94487'),
#  ObjectId('670adfd11d6415c0d0a94488'),
#  ObjectId('670adfd11d6415c0d0a94489'),
#  ObjectId('670adfd11d6415c0d0a9448a'),
#  ObjectId('670adfd11d6415c0d0a9448b'),
#  ObjectId('670adfd11d6415c0d0a9448c'),
#  ObjectId('670adfd11d6415c0d0a9448d'),
#  ObjectId('670adfd11d6415c0d0a9448e'),
#  ObjectId('670adfd11d6415c0d0a9448f'),
#  ObjectId('670adfd11d6415c0d0a94490'),
#  ObjectId('670adfd11d6415c0d0a94491'),
#  ObjectId('670adfd11d6415c0d0a94492'),
#  ObjectId('670adfd11d6415c0d0a94493'),
#  ObjectId('670adfd11d6415c0d0a94494'),
#  ObjectId('670adfd11d6415c0d0a94495'),
#  ObjectId('670adfd11d6415c0d0a94496'),
#  ObjectId('670adfd11d6415c0d0a94497'),
#  ObjectId('670adfd11d6415c0d0a94498'),
#  ObjectId('670adfd11d6415c0d0a94499'),
#  ObjectId('670adfd11d6415c0d0a9449a'),
#  ObjectId('670adfd11d6415c0d0a9449b'),
#  ObjectId('670adfd11d6415c0d0a9449c'),
#  ObjectId('670adfd11d6415c0d0a9449d'),
#  ObjectId('670adfd11d6415c0d0a9449e'),
#  ObjectId('670adfd11d6415c0d0a9449f'),
#  ObjectId('670adfd11d6415c0d0a944a0'),
#  ObjectId('670adfd11d6415c0d0a944a1'),
#  ObjectId('670adfd11d6415c0d0a944a2'),
#  ObjectId('670adfd11d6415c0d0a944a3'),
#  ObjectId('670adfd11d6415c0d0a944a4'),
#  ObjectId('670adfd11d6415c0d0a944a5'),
#  ObjectId('670adfd11d6415c0d0a944a6'),
#  ObjectId('670adfd11d6415c0d0a944a7'),
#  ObjectId('670adfd11d6415c0d0a944a8'),
#  ObjectId('670adfd11d6415c0d0a944a9'),
#  ObjectId('670adfd11d6415c0d0a944aa'),
#  ObjectId('670adfd11d6415c0d0a944ab'),
#  ...]

# %%
len(docs.inserted_ids)
# Out:
# 9435

# %%
collection.count_documents({})
# Out:
# 9436

# %% [markdown]
# **Removendo o registro de exemplo**

# %%
id_remover = collection.find_one()["_id"]
id_remover
# Out:
# ObjectId('670ade431d6415c0d0a940c3')

# %%
collection.delete_one({"_id": id_remover})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000198'), 'opTime': {'ts': Timestamp(1728766149, 23), 't': 408}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1728766149, 23), 'signature': {'hash': b'\x04|\x0c7\xcf\xb6\x1e\xb2\xb4\x83;\xf6\x12\xf5\xc3N\xc8q\x01\xff', 'keyId': 7363753473742995497}}, 'operationTime': Timestamp(1728766149, 23)}, acknowledged=True)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('670adfd11d6415c0d0a940c4'),
#  'Produto': 'Modelagem preditiva',
#  'Categoria do Produto': 'livros',
#  'Preço': 92.45,
#  'Frete': 5.6096965236,
#  'Data da Compra': '01/01/2020',
#  'Vendedor': 'Thiago Silva',
#  'Local da compra': 'BA',
#  'Avaliação da compra': 1,
#  'Tipo de pagamento': 'cartao_credito',
#  'Quantidade de parcelas': 3,
#  'lat': -13.29,
#  'lon': -41.71}

# %%
client.close()

# %% [markdown]
# ### Desafio 1 e 2: Desenvolvendo um Script

# %% [markdown]
# Até o momento temos desenvolvido nosso pipeline em um notebook Jupyter, que oferece um ambiente interativo e prático para o aprendizado e experimentação de novos conceitos e métodos. Agora, temos um novo desafio!
#
# Nosso objetivo é ter um pipeline de dados eficiente e automatizado. Portanto, para nos aproximarmos ainda mais dessa realidade, nosso próximo desafio é transformar o código que desenvolvemos até agora no nosso notebook em um script Python estruturado em funções.
#
# Essa abordagem traz vantagens como: facilidade de teste, reutilização de código, manutenção mais simples e automação do pipeline. Sem contar que, em um ambiente de produção, geralmente são utilizados scripts ao invés de notebooks. Então, bora desenvolver e praticar essa habilidade?
#
# **Orientações para o desafio**
#
# **Preparando o ambiente:**
#
# * crie uma subpasta chamada scripts na sua pasta de trabalho;
# * na pasta scripts crie um arquivo chamado "extract_and_save_data.py".
#
# **Desenvolvendo o código:**
#
# Para desenvolver as funções a seguir, você pode utilizar os códigos já feitos no notebook, adaptando-os para que se tornem funções, sendo elas:
#
# 1 - connect_mongo(uri): estabelece a conexão com a instância do MongoDB usando a URI fornecida. Ela retorna o cliente do MongoDB que permite interagir com o banco de dados.
#
# 2 - create_connect_db(client, db_name): utiliza o(a) cliente do MongoDB para criar (se não existir) e conectar-se ao banco de dados especificado pelo parâmetro db_name. Ela retorna o objeto de banco de dados que pode ser usado para interagir com as coleções dentro dele.
#
# 3 - create_connect_collection(db, col_name): cria (se não existir) e conecta-se à coleção especificada pelo parâmetro col_name dentro do banco de dados fornecido. Ela retorna o objeto de coleção que pode ser usado para interagir com os documentos dentro dela.
#
# 4 - extract_api_data(url): extrai dados de uma API na URL fornecida e retorna os dados extraídos no formato JSON.
#
# 5 - insert_data(col, data): recebe uma coleção e os dados que serão inseridos nela. Ela deve adicionar todos os documentos à coleção e retornar a quantidade de documentos inseridos.
#
# Com as funções prontas, o próximo desafio é executá-las, realizando os seguintes passos:
#
# * criar um novo banco de dados;
# * criar uma coleção;
# * extrair os dados da API: https://labdados.com/produtos;
# * inserir os dados da API na coleção criada.
#
# Se precisar de ajuda, na seção "Opinião da pessoa instrutora" você pode encontrar uma das formas de resolver o desafio proposto acima.
#
# **Código das funções**
#
# Nós podemos começar importando todas as bibliotecas que precisamos utilizar e em seguida construir as funções. Os códigos de cada função são basicamente os códigos que desenvolvemos no nosso notebook até o momento, a diferença é que estão adaptados de acordo com os parâmetros que cada função deve receber.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import requests

def connect_mongo(uri):
    # Criando um novo cliente e conectando ao servidor
    client = MongoClient(uri, server_api=ServerApi('1'))

    # Enviando um ping pra conferir se a conexão foi realizada
    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")
    except Exception as e:
        print(e)

    return client

def create_connect_db(client, db_name):
    db = client[db_name]
    return db

def create_connect_collection(db, col_name):
    return db[col_name]

def extract_api_data(url):
    return requests.get(url).json()

def insert_data(col, data):
    result = col.insert_many(data)
    n_docs_inseridos = len(result.inserted_ids)
    return n_docs_inseridos

# %% [markdown]
# Na função insert_data o trecho de código len(result.inserted_ids) retorna a quantidade de ids que foram inseridos na nossa base de dados, ou seja, a quantidade de documentos inseridos. Essa informação é importante para conseguirmos conferir se foram inseridos a quantidade de dados que esperávamos.
# **Executando as funções**
#
# Uma vez que as funções estão prontas, nós podemos executá-las para testar seu funcionamento. Para testá-las, vamos:
#
# * criar um banco de dados chamado "db_produtos_desafio";
# * criar uma coleção com o nome "produtos";
# * extrair os dados da API e adicioná-los à nossa coleção.
#
# O código a seguir foi desenvolvido no mesmo script de criação das funções:

# %%
if __name__ == "__main__":
    
    client = connect_mongo("mongodb+srv://pvreboucas:12345@cluster-pipeline.r7drw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster-pipeline")
    db = create_connect_db(client, "db_produtos_desafio")
    col = create_connect_collection(db, "produtos")

    data = extract_api_data("https://labdados.com/produtos")
    print(f"\nQuantidade de dados extraidos: {len(data)}")

    n_docs = insert_data(col, data)
    print(f"\nDocumentos inseridos na colecao: {n_docs}")

    client.close()

# %% [markdown]
# Entendendo o if __name__ == "__main__":
#
# O if __name__ == "__main__": é um código comum em Python e sua principal utilização é permitir ou impedir partes do código de serem executadas quando os módulos (scripts) são importados.
#
# Quando um módulo Python é importado, o Python define uma variável especial __name__ para esse módulo. Para o módulo que está sendo executado diretamente, o __name__ será sempre __main__. No entanto, para os que são importados, a variável __name__ será o nome do módulo.
#
# Assim, ao usar if __name__ == "__main__":, estamos essencialmente dizendo: "Execute este bloco de código apenas se este arquivo estiver sendo executado diretamente e não se ele estiver sendo importado por outro script."
#
# Isso permite que a gente tenha partes do código (geralmente testes ou exemplos) que podem ser executadas quando o arquivo é executado diretamente, mas que não serão executadas quando o arquivo é importado como módulo. Isso pode ser útil em situações em que você deseja usar suas funções em outro script, porém não quer que o código de teste seja executado nesse momento.
